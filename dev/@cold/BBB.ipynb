# %%
import os

folder_path = "/Users/laeh/Downloads/export-2025Aug13-3PM-optimized"

unique_names = set()

for filename in os.listdir(folder_path):
    if filename.lower().endswith(".jpg"):
        name = filename
        # Remove extension
        name = os.path.splitext(name)[0]
        # Remove "_preview" suffix if present
        if name.endswith("_preview"):
            name = name[:-8]
        unique_names.add(name)

for name in sorted(unique_names):
    print(name)
# Out:
# B.008.2005
# D.001.2005
# D.001.2006
# D.001.2007
# D.001.2008
# D.001.2011
# D.001.2013
# D.001.2014
# D.001.2016
# D.001.2017
# D.002.2005
# D.002.2006
# D.002.2007
# D.002.2008
# D.002.2011
# D.002.2012
# D.002.2013
# D.002.2016
# D.003.2005
# D.003.2006
# D.003.2007
# D.003.2008
# D.003.2011
# D.003.2013
# D.003.2016
# D.004.2005
# D.004.2006
# D.004.2008
# D.004.2012
# D.004.2013
# D.004.2016
# D.005.2005
# D.005.2011
# D.005.2012
# D.005.2013
# D.005.2016
# D.006.2005
# D.006.2012
# D.006.2013
# D.006.2016
# D.007.2012
# D.007.2013
# D.008.2012
# D.008.2013
# D.009.2012
# D.010.2012
# D.011.2012
# D.012.2012
# D.013.2013
# D.014.2012
# D.014.2013
# D.015.2012
# D.015.2013
# D.016.2012
# D.016.2013
# D.017.2012
# D.017.2013
# D.018.2012
# D.018.2013
# D.019.2012
# D.019.2013
# D.020.2012
# D.020.2013
# D.021.2012
# D.022.2012
# D.023.2012
# D.024.2012
# D.025.2012
# D.026.2012
# D.027.2012
# D.028.2012
# D.029.2012
# D.030.2012
# D.031.2012
# D.032.2012
# F.001.1998
# ...

# %%
Attached are:
	1.	“AlexHistoricalSpeechesContent.txt” — contains Alex’s past speeches.
Analyze this to learn Alex’s delivery style:
	•	Confident, high-energy, outcome-driven
	•	Short, punchy sentences with clean cadence
	•	Strategic repetition for emphasis
	•	Direct “What’s next” action calls for each team
	•	Urgency and “unreasonable velocity” in the close
Delivery traits to match:
	•	Pauses after key phrases for impact
	•	Emphasis on 2–4 key words per sentence
	•	Double-hit repetition for power (“We are DDN. And we… are unstoppable.”)
	•	Ideas grouped into short bursts for natural breathing
	2.	“Updates for Company Video – [DATE].docx” — contains the new updates for the upcoming speech.

⸻

Your task:

Produce only one output in Alex’s authentic delivery style — the performance-ready version — written for live or video delivery.

Formatting & style:
	•	Natural pacing: short bursts, pauses, repetition, and energy.
	•	Clear “What’s next” action items for each group and team.
	•	Tie every win to tangible customer business outcomes and value in the customer’s language.
	•	End with urgency, ownership, and “unreasonable velocity.”
	•	Numbered section titles in bold on the same line as the number (e.g., 1 DDN Wins Best in Show at Flash Memory Summit).
	•	Extra blank line between sections for readability.
	•	Occasional bold emphasis on key words or phrases.

⸻

Tone & focus rules:
	•	Speak in the customer’s language — avoid internal-only jargon.
	•	Show compelling, differentiated value clearly.
	•	Push Go-to-Market teams to actively hunt for new opportunities.
	•	Leverage partners and market momentum.
	•	Emulate NVIDIA’s clarity of value proposition and enhance it with DDN’s unique strengths.

⸻

Output format:
	•	Present the performance-ready speech directly in this chat in fully formatted text with bold emphasis where needed.
	•	Do not output any extra explanations, only the final speech.
